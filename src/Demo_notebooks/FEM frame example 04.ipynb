# %% [markdown]
# # A Finite Element Examples: Frame 04
#
# This example is based on the frame04 example distributed with FEM.edu
#
# This is a multi story frame system with three bays on each floor.

# %% [markdown]
# ## Load needed components

# %% [markdown]
# We need to add the local code to the path or python won't find FEM.edu

# %%
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join("..")))

# %% [markdown]
# Now load the needed components of FEM.edu

# %%
from femedu.domain import *
from femedu.solver.NewtonRaphsonSolver import *
from femedu.elements.Frame2D import *
from femedu.materials.ElasticSection import *

# %% [markdown]
# ## Build a model

# %%
# initialize a system model

N  = 8     # number of elements

B = 720.
H = 720.

E  = 29000.0
A = 150.0
I = 250.0

w = 0.10
load_at_nodes_only = False # set to True to apply equivalent nodal forces and moments

Ph = 0.00      # additional horizontal load per floor (imperfections)

# ========== setting global parameters ==============

target_load_level = 33.
max_steps = 10
load_levels = np.linspace(0, target_load_level, max_steps)

# ========= build your structural model =============

model = System()
model.setSolver(NewtonRaphsonSolver())

x0 = 0.0
x1 = B / 3
x2 = 2 * B / 3
x3 = B

y0 = 0.0
y1 = H / 4
y2 = 2 * H / 4
y3 = 3 * H / 4
y4 = H

X10 = Node(x0, y0)
X11 = Node(x0, y1)
X12 = Node(x0, y2)
X13 = Node(x0, y3)
X14 = Node(x0, y4)

X20 = Node(x1, y0)
X21 = Node(x1, y1)
X22 = Node(x1, y2)
X23 = Node(x1, y3)
X24 = Node(x1, y4)

X30 = Node(x2, y0)
X31 = Node(x2, y1)
X32 = Node(x2, y2)
X33 = Node(x2, y3)
X34 = Node(x2, y4)

X40 = Node(x3, y0)
X41 = Node(x3, y1)
X42 = Node(x3, y2)
X43 = Node(x3, y3)
X44 = Node(x3, y4)

model.addNode(X10,X11,X12,X13,X14)
model.addNode(X20,X21,X22,X23,X24)
model.addNode(X30,X31,X32,X33,X34)
model.addNode(X40,X41,X42,X43,X44)

# columns

params = {'E': E, 'A': A, 'I': I}

C11 = Frame2D(X10, X11, ElasticSection(params))
C12 = Frame2D(X11, X12, ElasticSection(params))
C13 = Frame2D(X12, X13, ElasticSection(params))
C14 = Frame2D(X13, X14, ElasticSection(params))

model.addElement(C11,C12,C13,C14)

params = {'E': E, 'A': 2*A, 'I': 1.5*I}

C21 = Frame2D(X20, X21, ElasticSection(params))
C22 = Frame2D(X21, X22, ElasticSection(params))
C23 = Frame2D(X22, X23, ElasticSection(params))
C24 = Frame2D(X23, X24, ElasticSection(params))

model.addElement(C21,C22,C23,C24)

C31 = Frame2D(X30, X31, ElasticSection(params))
C32 = Frame2D(X31, X32, ElasticSection(params))
C33 = Frame2D(X32, X33, ElasticSection(params))
C34 = Frame2D(X33, X34, ElasticSection(params))

model.addElement(C31,C32,C33,C34)

params = {'E': E, 'A': A, 'I': I}

C41 = Frame2D(X40, X41, ElasticSection(params))
C42 = Frame2D(X41, X42, ElasticSection(params))
C43 = Frame2D(X42, X43, ElasticSection(params))
C44 = Frame2D(X43, X44, ElasticSection(params))

model.addElement(C41,C42,C43,C44)

# floors

params = {'E': E, 'A': A, 'I': 3*I}

F11 = Frame2D(X11, X21, ElasticSection(params))
F12 = Frame2D(X21, X31, ElasticSection(params))
F13 = Frame2D(X31, X41, ElasticSection(params))

model.addElement(F11,F12,F13)

F21 = Frame2D(X12, X22, ElasticSection(params))
F22 = Frame2D(X22, X32, ElasticSection(params))
F23 = Frame2D(X32, X42, ElasticSection(params))

model.addElement(F21,F22,F23)

F31 = Frame2D(X13, X23, ElasticSection(params))
F32 = Frame2D(X23, X33, ElasticSection(params))
F33 = Frame2D(X33, X43, ElasticSection(params))

model.addElement(F31,F32,F33)

F41 = Frame2D(X14, X24, ElasticSection(params))
F42 = Frame2D(X24, X34, ElasticSection(params))
F43 = Frame2D(X34, X44, ElasticSection(params))

model.addElement(F41,F42,F43)

# fixities
X10.fixDOF('ux','uy','rz')   # fixed
X20.fixDOF('ux','uy','rz')   # fixed
X30.fixDOF('ux','uy','rz')   # fixed
X40.fixDOF('ux','uy','rz')   # fixed

# reference load
#Pcr = np.pi**2 * EI / L**2
model.resetLoad()            # size load vector and initialize
#model.addLoad(Xn, -Pcr, dof=0) # add a horizontal force (first dof only) ; remember C-style indexing: 0,1,...,(n-1)

if load_at_nodes_only:

    # floor loading as nodal loads ...

    Pe = w * B/3
    Mi = w * (B/3)**2 /12

    X11.addLoad([-Pe/2., -Mi],['uy','rz'])
    X21.addLoad([-Pe/2.,  0.],['uy','rz'])
    X31.addLoad([-Pe/2.,  0.],['uy','rz'])
    X41.addLoad([-Pe/2.,  Mi],['uy','rz'])

    X12.addLoad([-Pe/2., -Mi],['uy','rz'])
    X22.addLoad([-Pe/2.,  0.],['uy','rz'])
    X32.addLoad([-Pe/2.,  0.],['uy','rz'])
    X42.addLoad([-Pe/2.,  Mi],['uy','rz'])

    X13.addLoad([-Pe/2., -Mi],['uy','rz'])
    X23.addLoad([-Pe/2.,  0.],['uy','rz'])
    X33.addLoad([-Pe/2.,  0.],['uy','rz'])
    X43.addLoad([-Pe/2.,  Mi],['uy','rz'])

    X14.addLoad([-Pe/2., -Mi],['uy','rz'])
    X24.addLoad([-Pe/2.,  0.],['uy','rz'])
    X34.addLoad([-Pe/2.,  0.],['uy','rz'])
    X44.addLoad([-Pe/2.,  Mi],['uy','rz'])

else:

    # floor loading as distributed loads ...

    F11.setDistLoad(-w)
    F12.setDistLoad(-w)
    F13.setDistLoad(-w)

    F21.setDistLoad(-w)
    F22.setDistLoad(-w)
    F23.setDistLoad(-w)

    F31.setDistLoad(-w)
    F32.setDistLoad(-w)
    F33.setDistLoad(-w)

    F41.setDistLoad(-w)
    F42.setDistLoad(-w)
    F43.setDistLoad(-w)


# wind load ...

X11.addLoad([Ph],['ux'])   # horizontal load
X12.addLoad([Ph],['ux'])   # horizontal load
X13.addLoad([Ph],['ux'])   # horizontal load
X14.addLoad([Ph/2],['ux']) # horizontal load


# show model information
print(model)
# Out:
# System object
# Node0({'ux': 0, 'uy': 1, 'rz': 2}, x=[0. 0.], u=None)
# Node1({'ux': 0, 'uy': 1, 'rz': 2}, x=[  0. 180.], u=None)
# Node2({'ux': 0, 'uy': 1, 'rz': 2}, x=[  0. 360.], u=None)
# Node3({'ux': 0, 'uy': 1, 'rz': 2}, x=[  0. 540.], u=None)
# Node4({'ux': 0, 'uy': 1, 'rz': 2}, x=[  0. 720.], u=None)
# Node5({'ux': 0, 'uy': 1, 'rz': 2}, x=[240.   0.], u=None)
# Node6({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 180.], u=None)
# Node7({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 360.], u=None)
# Node8({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 540.], u=None)
# Node9({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 720.], u=None)
# Node10({'ux': 0, 'uy': 1, 'rz': 2}, x=[480.   0.], u=None)
# Node11({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 180.], u=None)
# Node12({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 360.], u=None)
# Node13({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 540.], u=None)
# Node14({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 720.], u=None)
# Node15({'ux': 0, 'uy': 1, 'rz': 2}, x=[720.   0.], u=None)
# Node16({'ux': 0, 'uy': 1, 'rz': 2}, x=[720. 180.], u=None)
# Node17({'ux': 0, 'uy': 1, 'rz': 2}, x=[720. 360.], u=None)
# Node18({'ux': 0, 'uy': 1, 'rz': 2}, x=[720. 540.], u=None)
# Node19({'ux': 0, 'uy': 1, 'rz': 2}, x=[720. 720.], u=None)
# Frame2D(Node0({'ux': 0, 'uy': 1, 'rz': 2}, x=[0. 0.], u=None),Node1({'ux': 0, 'uy': 1, 'rz': 2}, x=[  0. 180.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 250.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node1({'ux': 0, 'uy': 1, 'rz': 2}, x=[  0. 180.], u=None),Node2({'ux': 0, 'uy': 1, 'rz': 2}, x=[  0. 360.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 250.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node2({'ux': 0, 'uy': 1, 'rz': 2}, x=[  0. 360.], u=None),Node3({'ux': 0, 'uy': 1, 'rz': 2}, x=[  0. 540.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 250.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node3({'ux': 0, 'uy': 1, 'rz': 2}, x=[  0. 540.], u=None),Node4({'ux': 0, 'uy': 1, 'rz': 2}, x=[  0. 720.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 250.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node5({'ux': 0, 'uy': 1, 'rz': 2}, x=[240.   0.], u=None),Node6({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 180.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 300.0, 'I': 375.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node6({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 180.], u=None),Node7({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 360.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 300.0, 'I': 375.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node7({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 360.], u=None),Node8({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 540.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 300.0, 'I': 375.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node8({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 540.], u=None),Node9({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 720.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 300.0, 'I': 375.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node10({'ux': 0, 'uy': 1, 'rz': 2}, x=[480.   0.], u=None),Node11({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 180.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 300.0, 'I': 375.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node11({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 180.], u=None),Node12({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 360.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 300.0, 'I': 375.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node12({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 360.], u=None),Node13({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 540.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 300.0, 'I': 375.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node13({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 540.], u=None),Node14({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 720.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 300.0, 'I': 375.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node15({'ux': 0, 'uy': 1, 'rz': 2}, x=[720.   0.], u=None),Node16({'ux': 0, 'uy': 1, 'rz': 2}, x=[720. 180.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 250.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node16({'ux': 0, 'uy': 1, 'rz': 2}, x=[720. 180.], u=None),Node17({'ux': 0, 'uy': 1, 'rz': 2}, x=[720. 360.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 250.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node17({'ux': 0, 'uy': 1, 'rz': 2}, x=[720. 360.], u=None),Node18({'ux': 0, 'uy': 1, 'rz': 2}, x=[720. 540.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 250.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node18({'ux': 0, 'uy': 1, 'rz': 2}, x=[720. 540.], u=None),Node19({'ux': 0, 'uy': 1, 'rz': 2}, x=[720. 720.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 250.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node1({'ux': 0, 'uy': 1, 'rz': 2}, x=[  0. 180.], u=None),Node6({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 180.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node6({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 180.], u=None),Node11({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 180.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node11({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 180.], u=None),Node16({'ux': 0, 'uy': 1, 'rz': 2}, x=[720. 180.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node2({'ux': 0, 'uy': 1, 'rz': 2}, x=[  0. 360.], u=None),Node7({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 360.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node7({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 360.], u=None),Node12({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 360.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node12({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 360.], u=None),Node17({'ux': 0, 'uy': 1, 'rz': 2}, x=[720. 360.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node3({'ux': 0, 'uy': 1, 'rz': 2}, x=[  0. 540.], u=None),Node8({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 540.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node8({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 540.], u=None),Node13({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 540.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node13({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 540.], u=None),Node18({'ux': 0, 'uy': 1, 'rz': 2}, x=[720. 540.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node4({'ux': 0, 'uy': 1, 'rz': 2}, x=[  0. 720.], u=None),Node9({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 720.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node9({'ux': 0, 'uy': 1, 'rz': 2}, x=[240. 720.], u=None),Node14({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 720.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30}))
# Frame2D(Node14({'ux': 0, 'uy': 1, 'rz': 2}, x=[480. 720.], u=None),Node19({'ux': 0, 'uy': 1, 'rz': 2}, x=[720. 720.], u=None),ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30}))

# %% [markdown]
# ## Path-Following and Stability Analysis

# %%
# initialize the analysis:
model.resetDisplacements()   # set U to all zeros
model.setLoadFactor(0.0)     # define a known equilibrium solution

model.startRecorder()        # not doing anything yet, but will do the data collection soon

detKt   = []
lambdas = []

# solve for all load_levels
for loadfactor in load_levels:

    # define node X2 as the controled node; downward direction is prescribed:
    model.setLoadFactor(loadfactor)
    model.solve(verbose=True)

    # stability check
    lambdas.append(model.loadfactor)
    detKt.append(model.solver.checkStability())

    # report results
    print('+')
    #model.report()

    print("\n=== next load level ===\n")
    

print(lambdas)
print(detKt)
# Out:
# norm of the out-of-balance force:   0.0000e+00
# +
#
#  ** Stability check: (smallest eigenvalue of Kt) = 1.4498657938144892
#
# +
#
# === next load level ===
#
# norm of the out-of-balance force:   4.9858e+03
# norm of the out-of-balance force:   2.5683e+01
# norm of the out-of-balance force:   6.8753e-03
# norm of the out-of-balance force:   2.3811e-06
# norm of the out-of-balance force:   8.3602e-08
# +
#
#  ** Stability check: (smallest eigenvalue of Kt) = 1.3039611797648887
#
# +
#
# === next load level ===
#
# norm of the out-of-balance force:   4.9858e+03
# norm of the out-of-balance force:   5.2546e+01
# norm of the out-of-balance force:   2.8483e-02
# norm of the out-of-balance force:   2.0762e-05
# norm of the out-of-balance force:   9.5303e-08
# +
#
#  ** Stability check: (smallest eigenvalue of Kt) = 1.155824438714573
#
# +
#
# === next load level ===
#
# norm of the out-of-balance force:   4.9858e+03
# norm of the out-of-balance force:   8.0699e+01
# norm of the out-of-balance force:   6.6491e-02
# norm of the out-of-balance force:   7.4345e-05
# norm of the out-of-balance force:   1.0153e-07
# +
#
#  ** Stability check: (smallest eigenvalue of Kt) = 1.0049715576161442
#
# +
#
# === next load level ===
#
# norm of the out-of-balance force:   4.9858e+03
# norm of the out-of-balance force:   1.1028e+02
# norm of the out-of-balance force:   1.2275e-01
# norm of the out-of-balance force:   1.8724e-04
# norm of the out-of-balance force:   2.4149e-07
# +
#
#  ** Stability check: (smallest eigenvalue of Kt) = 0.8507250235457126
#
# +
#
# === next load level ===
#
# norm of the out-of-balance force:   4.9858e+03
# norm of the out-of-balance force:   1.4143e+02
# norm of the out-of-balance force:   1.9938e-01
# norm of the out-of-balance force:   3.8919e-04
# norm of the out-of-balance force:   6.5449e-07
# +
#
#  ** Stability check: (smallest eigenvalue of Kt) = 0.692094978528643
#
# +
#
# === next load level ===
#
# norm of the out-of-balance force:   4.9858e+03
# norm of the out-of-balance force:   1.7435e+02
# norm of the out-of-balance force:   2.9877e-01
# norm of the out-of-balance force:   7.1688e-04
# norm of the out-of-balance force:   1.4970e-06
# norm of the out-of-balance force:   1.5508e-08
# +
#
#  ** Stability check: (smallest eigenvalue of Kt) = 0.5275391348123213
#
# +
#
# === next load level ===
#
# norm of the out-of-balance force:   4.9858e+03
# norm of the out-of-balance force:   2.0925e+02
# norm of the out-of-balance force:   4.2361e-01
# norm of the out-of-balance force:   1.2154e-03
# norm of the out-of-balance force:   3.0751e-06
# norm of the out-of-balance force:   2.9220e-08
# +
#
#  ** Stability check: (smallest eigenvalue of Kt) = 0.3544285721187771
#
# +
#
# === next load level ===
#
# norm of the out-of-balance force:   4.9858e+03
# norm of the out-of-balance force:   2.4638e+02
# norm of the out-of-balance force:   5.7696e-01
# norm of the out-of-balance force:   1.9401e-03
# norm of the out-of-balance force:   5.8199e-06
# norm of the out-of-balance force:   2.1181e-08
# +
#
#  ** Stability check: (smallest eigenvalue of Kt) = 0.16763438925390067
#
# +
#
# === next load level ===
#
# norm of the out-of-balance force:   4.9858e+03
# norm of the out-of-balance force:   2.8607e+02
# norm of the out-of-balance force:   7.6225e-01
# norm of the out-of-balance force:   2.9585e-03
# norm of the out-of-balance force:   1.0388e-05
# norm of the out-of-balance force:   3.1016e-08
# +
#
#  ** Stability check: (smallest eigenvalue of Kt) = 0.04529626510621071
#
# +
#
# === next load level ===
#
# [0.0, 3.6666666666666665, 7.333333333333333, 11.0, 14.666666666666666, 18.333333333333332, 22.0, 25.666666666666664, 29.333333333333332, 33.0]
# [1.4498657938144892, 1.3039611797648887, 1.155824438714573, 1.0049715576161442, 0.8507250235457126, 0.692094978528643, 0.5275391348123213, 0.3544285721187771, 0.16763438925390067, 0.04529626510621071]

# %%
#
# ==== check the current state of the model ===
#

model.report()
# Out:
# System Analysis Report
# =======================
#
# Nodes:
# ---------------------
#   Node 0: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[0. 0.], fix:['ux', 'uy', 'rz'],
#           P:[0. 0. 0.], u:[0. 0. 0.]
#   Node 1: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[  0. 180.], fix:[],
#           P:[0. 0. 0.], u:[-0.00195269 -0.05845162 -0.02403623]
#   Node 2: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[  0. 360.], fix:[],
#           P:[0. 0. 0.], u:[ 0.00035802 -0.10234068 -0.01990617]
#   Node 3: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[  0. 540.], fix:[],
#           P:[0. 0. 0.], u:[-0.00103192 -0.13142317 -0.01829479]
#   Node 4: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[  0. 720.], fix:[],
#           P:[0. 0. 0.], u:[ 0.00479755 -0.14562156 -0.0304816 ]
#   Node 5: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[240.   0.], fix:['ux', 'uy', 'rz'],
#           P:[0. 0. 0.], u:[0. 0. 0.]
#   Node 6: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[240. 180.], fix:[],
#           P:[0. 0. 0.], u:[-0.00054966 -0.06909143  0.00451655]
#   Node 7: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[240. 360.], fix:[],
#           P:[0. 0. 0.], u:[ 4.92703015e-05 -1.20884831e-01  2.89826296e-03]
#   Node 8: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[240. 540.], fix:[],
#           P:[0. 0. 0.], u:[-0.00019519 -0.15550221  0.00208175]
#   Node 9: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[240. 720.], fix:[],
#           P:[0. 0. 0.], u:[ 0.00128191 -0.17298232  0.00685415]
#   Node 10: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[480.   0.], fix:['ux', 'uy', 'rz'],
#           P:[0. 0. 0.], u:[0. 0. 0.]
#   Node 11: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[480. 180.], fix:[],
#           P:[0. 0. 0.], u:[ 0.00054966 -0.06909143 -0.00451655]
#   Node 12: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[480. 360.], fix:[],
#           P:[0. 0. 0.], u:[-4.92702812e-05 -1.20884831e-01 -2.89826296e-03]
#   Node 13: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[480. 540.], fix:[],
#           P:[0. 0. 0.], u:[ 0.00019519 -0.15550221 -0.00208175]
#   Node 14: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[480. 720.], fix:[],
#           P:[0. 0. 0.], u:[-0.00128191 -0.17298232 -0.00685415]
#   Node 15: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[720.   0.], fix:['ux', 'uy', 'rz'],
#           P:[0. 0. 0.], u:[0. 0. 0.]
#   Node 16: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[720. 180.], fix:[],
#           P:[0. 0. 0.], u:[ 0.00195269 -0.05845162  0.02403623]
#   Node 17: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[720. 360.], fix:[],
#           P:[0. 0. 0.], u:[-0.00035802 -0.10234068  0.01990617]
#   Node 18: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[720. 540.], fix:[],
#           P:[0. 0. 0.], u:[ 0.00103192 -0.13142317  0.01829479]
#   Node 19: {'ux': 0, 'uy': 1, 'rz': 2}
#           x:[720. 720.], fix:[],
#           P:[0. 0. 0.], u:[-0.00479755 -0.14562156  0.0304816 ]
#
# Elements:
# ---------------------
#   Frame2D: node 0 to node 1:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 250.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -0.0003247312071908539, 'flexure': 0.0}   stress:{'axial': -1412.5807512802146, 'flexure': 0.0}
#      internal forces: f0=-1412.58 V0=-28.72 M0=2190.63 fl=-1412.58 Vl=-28.72 Ml=-2981.99 Pw=0.00 Mw=0.00
#   Frame2D: node 1 to node 2:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 250.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -0.0002438281388080467, 'flexure': 0.0}   stress:{'axial': -1060.6524038150033, 'flexure': 0.0}
#      internal forces: f0=-1060.65 V0=-54.15 M0=4967.18 fl=-1060.65 Vl=-54.15 Ml=-4777.61 Pw=0.00 Mw=0.00
#   Frame2D: node 2 to node 3:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 250.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -0.00016156938563946385, 'flexure': 0.0}   stress:{'axial': -702.8268275316677, 'flexure': 0.0}
#      internal forces: f0=-702.83 V0=-48.56 M0=4417.41 fl=-702.83 Vl=-48.56 Ml=-4323.51 Pw=0.00 Mw=0.00
#   Frame2D: node 3 to node 4:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 250.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -7.887991785609134e-05, 'flexure': 0.0}   stress:{'axial': -343.12764267399734, 'flexure': 0.0}
#      internal forces: f0=-343.13 V0=-63.72 M0=5307.41 fl=-343.13 Vl=-63.72 Ml=-6160.35 Pw=0.00 Mw=0.00
#   Frame2D: node 5 to node 6:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 300.0, 'I': 375.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -0.00038384129295629106, 'flexure': 0.0}   stress:{'axial': -3339.4192487197324, 'flexure': 0.0}
#      internal forces: f0=-3339.42 V0=7.47 M0=-673.83 fl=-3339.42 Vl=7.47 Ml=668.39 Pw=0.00 Mw=0.00
#   Frame2D: node 6 to node 7:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 300.0, 'I': 375.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -0.00028774110300976955, 'flexure': 0.0}   stress:{'axial': -2503.347596184995, 'flexure': 0.0}
#      internal forces: f0=-2503.35 V0=12.97 M0=-1196.02 fl=-2503.35 Vl=12.97 Ml=1140.41 Pw=0.00 Mw=0.00
#   Frame2D: node 7 to node 8:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 300.0, 'I': 375.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -0.00019231875545613157, 'flexure': 0.0}   stress:{'axial': -1673.1731724683445, 'flexure': 0.0}
#      internal forces: f0=-1673.17 V0=9.16 M0=-851.26 fl=-1673.17 Vl=9.16 Ml=797.45 Pw=0.00 Mw=0.00
#   Frame2D: node 8 to node 9:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 300.0, 'I': 375.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -9.711176520988577e-05, 'flexure': 0.0}   stress:{'axial': -844.8723573260062, 'flexure': 0.0}
#      internal forces: f0=-844.87 V0=17.25 M0=-1328.12 fl=-844.87 Vl=17.25 Ml=1778.43 Pw=0.00 Mw=0.00
#   Frame2D: node 10 to node 11:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 300.0, 'I': 375.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -0.00038384129295628244, 'flexure': 0.0}   stress:{'axial': -3339.4192487196574, 'flexure': 0.0}
#      internal forces: f0=-3339.42 V0=-7.47 M0=673.83 fl=-3339.42 Vl=-7.47 Ml=-668.39 Pw=0.00 Mw=0.00
#   Frame2D: node 11 to node 12:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 300.0, 'I': 375.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -0.0002877411030097639, 'flexure': 0.0}   stress:{'axial': -2503.347596184946, 'flexure': 0.0}
#      internal forces: f0=-2503.35 V0=-12.97 M0=1196.02 fl=-2503.35 Vl=-12.97 Ml=-1140.41 Pw=0.00 Mw=0.00
#   Frame2D: node 12 to node 13:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 300.0, 'I': 375.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -0.0001923187554561278, 'flexure': 0.0}   stress:{'axial': -1673.1731724683118, 'flexure': 0.0}
#      internal forces: f0=-1673.17 V0=-9.16 M0=851.26 fl=-1673.17 Vl=-9.16 Ml=-797.45 Pw=0.00 Mw=0.00
#   Frame2D: node 13 to node 14:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 300.0, 'I': 375.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -9.711176520988515e-05, 'flexure': 0.0}   stress:{'axial': -844.8723573260007, 'flexure': 0.0}
#      internal forces: f0=-844.87 V0=-17.25 M0=1328.12 fl=-844.87 Vl=-17.25 Ml=-1778.43 Pw=0.00 Mw=0.00
#   Frame2D: node 15 to node 16:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 250.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -0.00032473120719089577, 'flexure': 0.0}   stress:{'axial': -1412.5807512803965, 'flexure': 0.0}
#      internal forces: f0=-1412.58 V0=28.72 M0=-2190.63 fl=-1412.58 Vl=28.72 Ml=2981.99 Pw=0.00 Mw=0.00
#   Frame2D: node 16 to node 17:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 250.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -0.00024382813880805893, 'flexure': 0.0}   stress:{'axial': -1060.6524038150562, 'flexure': 0.0}
#      internal forces: f0=-1060.65 V0=54.15 M0=-4967.18 fl=-1060.65 Vl=54.15 Ml=4777.61 Pw=0.00 Mw=0.00
#   Frame2D: node 17 to node 18:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 250.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -0.00016156938563946564, 'flexure': 0.0}   stress:{'axial': -702.8268275316756, 'flexure': 0.0}
#      internal forces: f0=-702.83 V0=48.56 M0=-4417.41 fl=-702.83 Vl=48.56 Ml=4323.51 Pw=0.00 Mw=0.00
#   Frame2D: node 18 to node 19:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 250.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -7.887991785609073e-05, 'flexure': 0.0}   stress:{'axial': -343.12764267399467, 'flexure': 0.0}
#      internal forces: f0=-343.13 V0=63.72 M0=-5307.41 fl=-343.13 Vl=63.72 Ml=6160.35 Pw=0.00 Mw=0.00
#   Frame2D: node 1 to node 6:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': 5.84595579641116e-06, 'flexure': 0.0}   stress:{'axial': 25.429907714388545, 'flexure': 0.0}
#      internal forces: f0=25.43 V0=-44.07 M0=7890.83 fl=25.43 Vl=-44.07 Ml=-2686.63 Pw=-396.00 Mw=-15840.00
#   Frame2D: node 6 to node 11:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': 4.5804779641898494e-06, 'flexure': 0.0}   stress:{'axial': 19.925079144225844, 'flexure': 0.0}
#      internal forces: f0=19.93 V0=-0.00 M0=-822.22 fl=19.93 Vl=-0.00 Ml=-822.22 Pw=-396.00 Mw=-15840.00
#   Frame2D: node 11 to node 16:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': 5.84595579640431e-06, 'flexure': 0.0}   stress:{'axial': 25.429907714358748, 'flexure': 0.0}
#      internal forces: f0=25.43 V0=44.07 M0=-2686.63 fl=25.43 Vl=44.07 Ml=7890.83 Pw=-396.00 Mw=-15840.00
#   Frame2D: node 2 to node 7:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -1.2864579457049863e-06, 'flexure': 0.0}   stress:{'axial': -5.59609206381669, 'flexure': 0.0}
#      internal forces: f0=-5.60 V0=-38.17 M0=6644.98 fl=-5.60 Vl=-38.17 Ml=-2516.78 Pw=-396.00 Mw=-15840.00
#   Frame2D: node 7 to node 12:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -4.105857609672803e-07, 'flexure': 0.0}   stress:{'axial': -1.7860480602076692, 'flexure': 0.0}
#      internal forces: f0=-1.79 V0=-0.00 M0=-525.10 fl=-1.79 Vl=-0.00 Ml=-525.10 Pw=-396.00 Mw=-15840.00
#   Frame2D: node 12 to node 17:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -1.2864579457051379e-06, 'flexure': 0.0}   stress:{'axial': -5.59609206381735, 'flexure': 0.0}
#      internal forces: f0=-5.60 V0=38.17 M0=-2516.78 fl=-5.60 Vl=38.17 Ml=6644.98 Pw=-396.00 Mw=-15840.00
#   Frame2D: node 3 to node 8:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': 3.4863636345737456e-06, 'flexure': 0.0}   stress:{'axial': 15.165681810395794, 'flexure': 0.0}
#      internal forces: f0=15.17 V0=-36.30 M0=6209.08 fl=15.17 Vl=-36.30 Ml=-2503.48 Pw=-396.00 Mw=-15840.00
#   Frame2D: node 8 to node 13:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': 1.6266230904427424e-06, 'flexure': 0.0}   stress:{'axial': 7.0758104434259295, 'flexure': 0.0}
#      internal forces: f0=7.08 V0=0.00 M0=-377.91 fl=7.08 Vl=0.00 Ml=-377.91 Pw=-396.00 Mw=-15840.00
#   Frame2D: node 13 to node 18:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': 3.4863636345743254e-06, 'flexure': 0.0}   stress:{'axial': 15.165681810398315, 'flexure': 0.0}
#      internal forces: f0=15.17 V0=36.30 M0=-2503.48 fl=15.17 Vl=36.30 Ml=6209.08 Pw=-396.00 Mw=-15840.00
#   Frame2D: node 4 to node 9:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -1.4648487336473044e-05, 'flexure': 0.0}   stress:{'axial': -63.72091991365774, 'flexure': 0.0}
#      internal forces: f0=-63.72 V0=-52.87 M0=9679.65 fl=-63.72 Vl=-52.87 Ml=-3007.97 Pw=-396.00 Mw=-15840.00
#   Frame2D: node 9 to node 14:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -1.0682585733089801e-05, 'flexure': 0.0}   stress:{'axial': -46.46924793894063, 'flexure': 0.0}
#      internal forces: f0=-46.47 V0=0.00 M0=-1229.55 fl=-46.47 Vl=0.00 Ml=-1229.55 Pw=-396.00 Mw=-15840.00
#   Frame2D: node 14 to node 19:
#      material properties: ElasticSection(Material)({'E': 29000.0, 'A': 150.0, 'I': 750.0, 'nu': 0.0, 'fy': 1e+30})  strain:{'axial': -1.4648487336475693e-05, 'flexure': 0.0}   stress:{'axial': -63.72091991366926, 'flexure': 0.0}
#      internal forces: f0=-63.72 V0=52.87 M0=-3007.97 fl=-63.72 Vl=52.87 Ml=9679.65 Pw=-396.00 Mw=-15840.00

# %%
#
# ==== create some nice plots ===
#

plt.plot(lambdas,detKt,'--*r')
plt.grid(True)
plt.xlabel('Load factor, $ \lambda $')
plt.ylabel("Stability index, $ {det}\: {\\bf K}_t $")
plt.show()

model.plot(factor=10.0)

model.beamValuePlot("F")
model.beamValuePlot("M")
model.beamValuePlot("V")

# %%
# buckling (mode) shapes can be computed and plotted as well
#
# mode=0 is the closest mode.  This is the default

model.plotBucklingMode(factor=200.)

# %%
model.plotBucklingMode(mode=1,factor=200.)

# %%
model.plotBucklingMode(mode=2,factor=200.)

# %%
model.plotBucklingMode(mode=3,factor=200.)
